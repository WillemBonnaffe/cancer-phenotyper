# %% [markdown]
# # GlandSeg Classification Script

# %% [markdown]
# ## To do next:
# * Improve augmentations to simulate change in staining --> Re-train contrastive learning encoder.
# * Implement saving mask of each gland --> Refine visualisations of gland clusters in situ.

# %%
##############
## INITIATE ##
##############

## Imports
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2
import torch
import pickle
from PIL import Image
from torchvision import transforms
from sklearn.neighbors import KNeighborsClassifier

## Import modules
from f_wsi_reader import slide_path_to_tiles_at_coordinates
from f_wsi_reader import get_tile_map
from f_wsi_reader import get_tile_map_fast
from f_wsi_reader import read_slide
from f_wsi_reader import get_dimensions
from f_wsi_reader import apply_all_filters
from f_wsi_reader import apply_all_transforms
from f_wsi_reader import reassemble_tiles
from f_wsi_reader import select_patches_on_grid
from f_wsi_reader import get_tissue_mask
from f_extract_objects import extract_object_pixels
from f_extract_objects import polish
from f_extract_objects import inlay_objects
from f_extract_objects import get_bounding_box_square
# from f_model import UNet as Model
from f_model_transformer import UNetTransformer as Model

#
###
# Out:
# /Users/willembonnaffe/anaconda3/envs/pytorch/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
###############
## FUNCTIONS ##
###############

def load_encoder(encoder_path, device='cpu'):
    """
    Loads a pre-trained ResNet18 encoder.

    Args:
        encoder_path (str): Path to the saved encoder weights.
        device (str): Device to load the encoder onto ('cpu' or 'cuda').

    Returns:
        torch.nn.Module: The loaded ResNet18 encoder.
    """
    from torchvision.models import resnet18
    
    # Define the encoder class (ResNet18 without classification layer)
    class ResNet18Encoder(torch.nn.Module):
        def __init__(self):
            super(ResNet18Encoder, self).__init__()
            self.resnet18 = resnet18(pretrained=True)
            self.resnet18 = torch.nn.Sequential(*list(self.resnet18.children())[:-1])  # Remove the FC layer
            self.flatten = torch.nn.Flatten()

        def forward(self, x):
            x = self.resnet18(x)
            x = self.flatten(x)
            return x
    
    # Initialize and load the encoder
    encoder = ResNet18Encoder()
    encoder.load_state_dict(torch.load(encoder_path, map_location=device))
    encoder.to(device)
    encoder.eval()  # Set to evaluation mode
    return encoder

def load_knn_classifier(knn_model_path):
    """
    Loads the pre-trained k-NN classifier from a file.

    Args:
        knn_model_path (str): Path to the saved k-NN classifier file.

    Returns:
        KNeighborsClassifier: The loaded k-NN classifier.
    """
    with open(knn_model_path, 'rb') as f:
        knn_classifier = pickle.load(f)
    return knn_classifier

def encode_image(image_path, encoder):
    """
    Encodes an image into its high-dimensional embedding using the pre-trained encoder.
    
    Args:
        image_path (str): Path to the input image.
        encoder (torch.nn.Module): Pre-trained ResNet18 encoder.        
    
    Returns:
        torch.Tensor: The high-dimensional embedding of the image.
    """
    ## Load and preprocess the image
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    
    ## Apply preprocessing: CLAHE, resize, normalization
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    image = cv2.cvtColor(image, cv2.COLOR_RGB2LAB)
    l, a, b = cv2.split(image)
    l = clahe.apply(l)
    image = cv2.merge((l, a, b))
    image = cv2.cvtColor(image, cv2.COLOR_LAB2RGB)
    image = cv2.resize(image, (224, 224))

    ## Convert image to PIL format for transforms
    image = Image.fromarray(image)

    ## Define the same transformation pipeline used during training
    transform = transforms.Compose([    
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

    ## Transformations
    image = transform(image)  # Apply the same transformation pipeline used during training

    ## Add a batch dimension (for a single image)
    image = image.unsqueeze(0)

    ## Ensure the encoder is in evaluation mode
    encoder.eval()

    ## Generate the embedding
    with torch.no_grad():  # Disable gradients for inference
        embedding = encoder(image)

    return embedding

def predict_cluster(image_embedding, knn_classifier):
    """
    Predicts the cluster for a given image embedding using the pre-trained k-NN classifier.
    
    Args:
        image_embedding (torch.Tensor): The embedding of the image.
        knn_classifier (sklearn.neighbors.KNeighborsClassifier): Pre-trained k-NN classifier.
    
    Returns:
        int: The predicted cluster label.
    """
    ## Convert the embedding to a NumPy array (k-NN expects NumPy input)
    image_embedding_np = image_embedding.cpu().numpy()

    ## Predict the cluster using k-NN
    predicted_cluster = knn_classifier.predict(image_embedding_np)

    return predicted_cluster[0]  # Return the predicted cluster label

#
###

# %%
#########################
## INITIATE CLASSIFIER ##
#########################

## Paths to the pre-trained encoder and k-NN classifier
encoder_path = '/Users/willembonnaffe/Documents/GitHub/GlandSeg/scripts/b2_0_0/p_classify_glands/scripts/V0_0_0/model_TCGA_V0_3.pth'
knn_model_path = '/Users/willembonnaffe/Documents/GitHub/GlandSeg/scripts/b2_0_0/p_classify_glands/scripts/V0_0_0/knn_classifier.pkl'

## Device setup
device = 'cpu'  # or 'cuda' if GPU is available

## Load the pre-trained ResNet18 encoder
encoder = load_encoder(encoder_path, device=device)

## Load the pre-trained k-NN classifier
knn_classifier = load_knn_classifier(knn_model_path)

#
###
# Out:
# /Users/willembonnaffe/anaconda3/envs/pytorch/lib/python3.8/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Users/willembonnaffe/anaconda3/envs/pytorch/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
######################
## APPLY CLASSIFIER ##
######################

## Parameters
PTIF = '/Users/willembonnaffe/Documents/Academia/Projects/GlandSeg/V2_0_0/TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs_extracted_glands/'
# PTIF = '/Users/willembonnaffe/Documents/Academia/Projects/GlandSeg/V2_0_0/TB10.1062_V1_11.svs_extracted_glands/'
image_paths = os.listdir(PTIF)
image_paths = [PTIF + image_path for image_path in image_paths] # Add root

cluster_labels = []
coords_list = []
for image_path in image_paths:

    ## Check path
    print(os.path.basename(image_path))

    image_name = os.path.basename(image_path)    
    name = image_name.replace('.png','').replace('.svs','').split('__')[0]
    coords_list += [image_name.replace('.png','').replace('.svs','').split('__')[1].split('_')]
   
    ## Encode the new image to obtain its embedding
    image_embedding = encode_image(image_path, encoder)
    
    ## Predict the cluster for the new image using the k-NN classifier
    predicted_cluster = predict_cluster(image_embedding, knn_classifier)
    print(f'The predicted cluster for the image is: {predicted_cluster}')

    ## Collect
    cluster_labels += [predicted_cluster]    

#
###
# Out:
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__49064_50360_28272_29568.png
# The predicted cluster for the image is: 8
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__42144_42512_30064_30432.png
# The predicted cluster for the image is: 9
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__28720_28768_12736_12784.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__23112_23368_33376_33632.png
# The predicted cluster for the image is: 7
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__42800_42896_21240_21336.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__24704_24752_25632_25680.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__52488_52792_24192_24496.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__41888_42128_22248_22488.png
# The predicted cluster for the image is: 5
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__42616_43240_28672_29296.png
# The predicted cluster for the image is: 8
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__12336_12880_11776_12320.png
# The predicted cluster for the image is: 5
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__47104_47776_19032_19704.png
# The predicted cluster for the image is: 9
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__33376_33504_13800_13928.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__18576_18720_20160_20304.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__11664_11808_12544_12688.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__39296_39536_16928_17168.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__40704_40800_32808_32904.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__40256_40416_13888_14048.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__29856_30128_8816_9088.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__26992_28224_32584_33816.png
# The predicted cluster for the image is: 8
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__11168_11232_17696_17760.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__34336_34512_8960_9136.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__46896_47152_19696_19952.png
# The predicted cluster for the image is: 6
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__34944_35056_24112_24224.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__32704_32944_16112_16352.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__39264_39312_17504_17552.png
# The predicted cluster for the image is: 7
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__12808_12840_29104_29136.png
# The predicted cluster for the image is: 7
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__35584_35808_18312_18536.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__21360_21600_13328_13568.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__37856_37920_18368_18432.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__36864_37232_18144_18512.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__47376_47472_14968_15064.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__10768_10832_25008_25072.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__43464_43576_21504_21616.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__40560_41392_27448_28280.png
# The predicted cluster for the image is: 8
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__19096_19128_26128_26160.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__42392_42488_22112_22208.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__9576_9704_26416_26544.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__40592_40656_32128_32192.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__43232_43520_20368_20656.png
# The predicted cluster for the image is: 7
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__47776_47824_14384_14432.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__44680_44728_18432_18480.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__37568_37648_8632_8712.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__41456_41552_24936_25032.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__13040_13232_30448_30640.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__35648_36496_14312_15160.png
# The predicted cluster for the image is: 5
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__22672_22720_34640_34688.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__15072_15152_12256_12336.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__34128_34144_42464_42480.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__12384_12464_29520_29600.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__38632_38744_31968_32080.png
# The predicted cluster for the image is: 6
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__45688_45992_22288_22592.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__23312_23664_12176_12528.png
# The predicted cluster for the image is: 5
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__7424_7616_21528_21720.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__16904_16952_16800_16848.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__47768_47912_27424_27568.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__38768_38864_35064_35160.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__41920_42096_20056_20232.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__41704_41944_15872_16112.png
# The predicted cluster for the image is: 7
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__28672_28768_34512_34608.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__16752_17584_19488_20320.png
# The predicted cluster for the image is: 5
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__33992_34168_9360_9536.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__41984_42208_12448_12672.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__6776_7000_22176_22400.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__28384_28432_9608_9656.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__26944_27600_14160_14816.png
# The predicted cluster for the image is: 9
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__12176_12208_24112_24144.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__49016_49240_26128_26352.png
# The predicted cluster for the image is: 6
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__42928_43024_10736_10832.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__14160_14288_25384_25512.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__41680_41792_34328_34440.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__32368_32464_24472_24568.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__32832_32864_12240_12272.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__18688_18784_16136_16232.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__52160_52304_24536_24680.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__22272_22496_15280_15504.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__24152_24616_32928_33392.png
# The predicted cluster for the image is: 9
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__21728_21840_12216_12328.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__16928_17440_23664_24176.png
# The predicted cluster for the image is: 9
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__37240_37368_17792_17920.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__43512_43560_8784_8832.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__37248_37312_18056_18120.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__40688_40768_18192_18272.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__31616_31680_31384_31448.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__47320_47480_17104_17264.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__36408_36488_33808_33888.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__32176_32544_21312_21680.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__28672_29200_15376_15904.png
# The predicted cluster for the image is: 5
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__42288_42528_16656_16896.png
# The predicted cluster for the image is: 7
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__11136_11216_20648_20728.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__27392_28224_27800_28632.png
# The predicted cluster for the image is: 8
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__31824_31920_14416_14512.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__11160_11496_20160_20496.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__22608_22896_33768_34056.png
# The predicted cluster for the image is: 5
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__6224_6320_26872_26968.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__7520_7584_21992_22056.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__35648_35984_20480_20816.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__47472_47616_15056_15200.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__23008_23136_10560_10688.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__32824_32872_13648_13696.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__47448_47608_16128_16288.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__47160_47288_32048_32176.png
# The predicted cluster for the image is: 7
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__18864_18976_24200_24312.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__14848_14896_29736_29784.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__14304_14480_10192_10368.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__26704_26960_27376_27632.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__19024_19264_13808_14048.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__40904_41144_31344_31584.png
# The predicted cluster for the image is: 6
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__29664_29792_11808_11936.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__49344_49392_27680_27728.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__20680_21016_18368_18704.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__43616_43696_23064_23144.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__19584_19632_13448_13496.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__18320_18480_31888_32048.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__32104_32616_28064_28576.png
# The predicted cluster for the image is: 5
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__42864_42912_29976_30024.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__24392_24664_29104_29376.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__36848_36896_19184_19232.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__46072_46296_26144_26368.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__39256_39288_29488_29520.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__43416_44312_33440_34336.png
# The predicted cluster for the image is: 5
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__20464_20864_16000_16400.png
# The predicted cluster for the image is: 5
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__37712_38160_33040_33488.png
# The predicted cluster for the image is: 9
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__23552_23728_19808_19984.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__36656_36816_13408_13568.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__37168_37280_29896_30008.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__38352_39200_15072_15920.png
# The predicted cluster for the image is: 8
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__41424_41472_24760_24808.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__46208_47184_17680_18656.png
# The predicted cluster for the image is: 5
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__47760_48080_19872_20192.png
# The predicted cluster for the image is: 9
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__40688_40992_14640_14944.png
# The predicted cluster for the image is: 7
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__48880_48912_19856_19888.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__50848_51072_20072_20296.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__18360_18392_25712_25744.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__41808_42448_26856_27496.png
# The predicted cluster for the image is: 9
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__44176_44320_16304_16448.png
# The predicted cluster for the image is: 7
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__30736_30768_9776_9808.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__10576_10752_13304_13480.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__21536_21632_21632_21728.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__10712_10760_17568_17616.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__20552_20712_10880_11040.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__22640_22704_17976_18040.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__41264_41408_21360_21504.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__47072_47312_28608_28848.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__16624_16656_15032_15064.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__33152_33296_18320_18464.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__30960_31728_30416_31184.png
# The predicted cluster for the image is: 8
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__6976_7488_25760_26272.png
# The predicted cluster for the image is: 9
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__38640_38720_22432_22512.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__43936_44064_29072_29200.png
# The predicted cluster for the image is: 5
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__24112_24464_20976_21328.png
# The predicted cluster for the image is: 9
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__40832_40864_30056_30088.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__40120_40168_32144_32192.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__17584_18896_21136_22448.png
# The predicted cluster for the image is: 8
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__38424_38568_32144_32288.png
# The predicted cluster for the image is: 7
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__37320_37688_25424_25792.png
# The predicted cluster for the image is: 9
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__44800_44928_18832_18960.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__28784_29104_14248_14568.png
# The predicted cluster for the image is: 9
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__22640_22672_28432_28464.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__43776_43888_34408_34520.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__47360_47728_23584_23952.png
# The predicted cluster for the image is: 9
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__29080_29160_12816_12896.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__26280_26456_26832_27008.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__25296_30000_23728_28432.png
# The predicted cluster for the image is: 8
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__38240_38624_34328_34712.png
# The predicted cluster for the image is: 5
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__46320_46368_17624_17672.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__7744_7856_26920_27032.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__41480_42456_22544_23520.png
# The predicted cluster for the image is: 8
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__33312_33440_30320_30448.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__43488_43568_12856_12936.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__41256_41416_14080_14240.png
# The predicted cluster for the image is: 7
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__41808_41872_34168_34232.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__51008_51136_21184_21312.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__11296_11440_22064_22208.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__50496_51520_23816_24840.png
# The predicted cluster for the image is: 8
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__45368_45448_12704_12784.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__46848_47440_30008_30600.png
# The predicted cluster for the image is: 9
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__26160_26176_26528_26544.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__21904_21968_14144_14208.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__12088_12280_12672_12864.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__41536_41696_20912_21072.png
# The predicted cluster for the image is: 7
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__32896_33024_34568_34696.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__10224_10336_19008_19120.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__23456_23536_10472_10552.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__35592_35624_14352_14384.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__49920_49968_21168_21216.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__33984_34096_11192_11304.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__14904_14952_25888_25936.png
# The predicted cluster for the image is: 7
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__41712_41792_19480_19560.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__31064_31096_30144_30176.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__50400_50432_19096_19128.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__42872_42968_27648_27744.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__22800_23328_11808_12336.png
# The predicted cluster for the image is: 9
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__38696_38952_34304_34560.png
# The predicted cluster for the image is: 5
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__38992_39264_34784_35056.png
# The predicted cluster for the image is: 7
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__28512_28576_32784_32848.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__8320_8576_25696_25952.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__8296_8424_20032_20160.png
# The predicted cluster for the image is: 7
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__33120_33200_15208_15288.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__42256_42288_18488_18520.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__31808_31936_15104_15232.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__35952_37664_31456_33168.png
# The predicted cluster for the image is: 8
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__39264_39888_30400_31024.png
# The predicted cluster for the image is: 5
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__34176_34240_33464_33528.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__35424_35696_9576_9848.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__7616_8080_24680_25144.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__28400_29056_18464_19120.png
# The predicted cluster for the image is: 8
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__41600_41648_15088_15136.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__42720_42864_19360_19504.png
# The predicted cluster for the image is: 7
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__9264_9408_23448_23592.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__36768_37456_14976_15664.png
# The predicted cluster for the image is: 8
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__7328_7472_22528_22672.png
# The predicted cluster for the image is: 6
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__19008_19040_22440_22472.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__31856_31936_12016_12096.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__39120_39152_10704_10736.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__44624_44784_16800_16960.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__34624_35024_34240_34640.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__41616_41648_9880_9912.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__44680_44904_16144_16368.png
# The predicted cluster for the image is: 7
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__6448_6512_21152_21216.png
# The predicted cluster for the image is: 7
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__39840_39952_13552_13664.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__44592_44752_33128_33288.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__38000_38064_19000_19064.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__46032_46112_29816_29896.png
# The predicted cluster for the image is: 7
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__26320_26400_36128_36208.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__45808_46208_16352_16752.png
# The predicted cluster for the image is: 7
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__16160_16224_14112_14176.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__38408_38728_33600_33920.png
# The predicted cluster for the image is: 9
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__38544_38688_28728_28872.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__41168_41200_30672_30704.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__46264_46344_31808_31888.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__40920_41144_23056_23280.png
# The predicted cluster for the image is: 7
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__48680_48728_22320_22368.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__39216_39328_29200_29312.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__6608_6880_19904_20176.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__26440_27016_13744_14320.png
# The predicted cluster for the image is: 5
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__26832_29680_15920_18768.png
# The predicted cluster for the image is: 8
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__10584_10632_29040_29088.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__8464_8544_20696_20776.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__44048_44080_14224_14256.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__40016_40112_30872_30968.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__13928_14008_23904_23984.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__41856_42544_24480_25168.png
# The predicted cluster for the image is: 5
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__15808_15904_32768_32864.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__48032_48352_29216_29536.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__36896_37040_16536_16680.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__11616_11952_27184_27520.png
# The predicted cluster for the image is: 6
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__23296_23344_27984_28032.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__16656_16688_26672_26704.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__47800_47960_28704_28864.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__36432_36640_12696_12904.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__22640_23024_15960_16344.png
# The predicted cluster for the image is: 5
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__21280_22112_10064_10896.png
# The predicted cluster for the image is: 8
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__16408_16472_11232_11296.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__23168_23216_10280_10328.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__45952_46160_23408_23616.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__22592_22784_15504_15696.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__31296_32688_24464_25856.png
# The predicted cluster for the image is: 8
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__6576_6672_23928_24024.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__14408_14456_24096_24144.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__47176_47256_27616_27696.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__41216_41264_9904_9952.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__8560_8736_19072_19248.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__47744_47952_13440_13648.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__46480_47504_15696_16720.png
# The predicted cluster for the image is: 8
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__4608_4656_26064_26112.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__31488_31520_12000_12032.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__51264_51392_26368_26496.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__32688_33456_28088_28856.png
# The predicted cluster for the image is: 5
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__45056_45232_33200_33376.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__48384_48480_16600_16696.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__44352_44592_19712_19952.png
# The predicted cluster for the image is: 5
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__21392_21888_22400_22896.png
# The predicted cluster for the image is: 9
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__37424_37552_33984_34112.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__32992_33024_33848_33880.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__38480_38928_31544_31992.png
# The predicted cluster for the image is: 6
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__13696_13808_25568_25680.png
# The predicted cluster for the image is: 7
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__40640_41136_30200_30696.png
# The predicted cluster for the image is: 9
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__40896_41200_32200_32504.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__8992_9104_24744_24856.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__42472_42584_18752_18864.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__14752_14784_29520_29552.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__41520_41552_8144_8176.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__44832_44976_25120_25264.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__34456_34568_15488_15600.png
# The predicted cluster for the image is: 6
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__47760_47936_19120_19296.png
# The predicted cluster for the image is: 7
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__34224_34288_13912_13976.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__34480_34848_12272_12640.png
# The predicted cluster for the image is: 5
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__13776_14064_26160_26448.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__45600_45808_18280_18488.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__39312_39424_23296_23408.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__24624_24752_35120_35248.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__26128_27824_12200_13896.png
# The predicted cluster for the image is: 8
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__49920_49968_20800_20848.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__17584_17728_25552_25696.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__42032_42224_19816_20008.png
# The predicted cluster for the image is: 7
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__47264_47392_28192_28320.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__40344_40728_20560_20944.png
# The predicted cluster for the image is: 9
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__35968_36240_31504_31776.png
# The predicted cluster for the image is: 9
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__33568_33664_18136_18232.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__33232_33344_33072_33184.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__7504_7856_21008_21360.png
# The predicted cluster for the image is: 5
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__40768_40816_17008_17056.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__45648_46064_31136_31552.png
# The predicted cluster for the image is: 5
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__19520_19616_24352_24448.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__27392_27488_23032_23128.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__11888_12000_24112_24224.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__39560_39688_27456_27584.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__44160_44176_24640_24656.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__21488_21680_11552_11744.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__34560_34624_42704_42768.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__38656_39248_24640_25232.png
# The predicted cluster for the image is: 8
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__12032_12160_19360_19488.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__7808_7856_21744_21792.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__44880_45520_22752_23392.png
# The predicted cluster for the image is: 5
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__50160_50384_20848_21072.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__50936_51032_20704_20800.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__20672_21632_16448_17408.png
# The predicted cluster for the image is: 8
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__28000_28176_34168_34344.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__34816_35200_22584_22968.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__30312_31192_17920_18800.png
# The predicted cluster for the image is: 8
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__29696_30160_34080_34544.png
# The predicted cluster for the image is: 9
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__26544_26608_36944_37008.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__39072_39328_19752_20008.png
# The predicted cluster for the image is: 7
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__33768_33848_35376_35456.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__26480_27088_34216_34824.png
# The predicted cluster for the image is: 5
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__43920_44352_29824_30256.png
# The predicted cluster for the image is: 9
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__43024_43120_33440_33536.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__44400_44832_22440_22872.png
# The predicted cluster for the image is: 5
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__22272_22384_12224_12336.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__42168_42568_19968_20368.png
# The predicted cluster for the image is: 6
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__30848_31120_33160_33432.png
# The predicted cluster for the image is: 9
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__32304_32432_17176_17304.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__47528_47784_29136_29392.png
# The predicted cluster for the image is: 6
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__12792_12856_20400_20464.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__22704_23008_30872_31176.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__36400_36912_16768_17280.png
# The predicted cluster for the image is: 9
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__44512_44864_14624_14976.png
# The predicted cluster for the image is: 5
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__41648_42112_23648_24112.png
# The predicted cluster for the image is: 5
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__36608_36704_41376_41472.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__21896_22008_11312_11424.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__28304_28384_15920_16000.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__39184_39248_28808_28872.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__32576_32640_9496_9560.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__46976_47088_23096_23208.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__18848_18912_22768_22832.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__28256_28384_25472_25600.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__45824_45856_13776_13808.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__45152_45744_24360_24952.png
# The predicted cluster for the image is: 8
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__26112_26160_13872_13920.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__28880_28960_13784_13864.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__45584_45648_13128_13192.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__40864_40896_14104_14136.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__49328_49568_27056_27296.png
# The predicted cluster for the image is: 10
# ...
# The predicted cluster for the image is: 5
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__48016_48304_23216_23504.png
# The predicted cluster for the image is: 5
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__37928_38072_18192_18336.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__47336_47464_20416_20544.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__9344_10160_17392_18208.png
# The predicted cluster for the image is: 8
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__30432_31136_19824_20528.png
# The predicted cluster for the image is: 8
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__42128_42288_25656_25816.png
# The predicted cluster for the image is: 7
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__41728_41968_23504_23744.png
# The predicted cluster for the image is: 5
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__21744_21808_33744_33808.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__11344_11536_27056_27248.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__39040_39552_33440_33952.png
# The predicted cluster for the image is: 8
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__16744_16808_28016_28080.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__41872_42016_29888_30032.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__25984_26384_14000_14400.png
# The predicted cluster for the image is: 5
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__29056_29120_9736_9800.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__45328_45664_33400_33736.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__45376_45536_32176_32336.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__27824_28048_18232_18456.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__37248_37840_22608_23200.png
# The predicted cluster for the image is: 9
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__43504_43600_11696_11792.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__27864_28072_36240_36448.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__38160_38192_22480_22512.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__33360_33488_24912_25040.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__43360_43408_17048_17096.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__48656_48704_20288_20336.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__17544_18264_9680_10400.png
# The predicted cluster for the image is: 9
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__16128_16240_33664_33776.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__19336_19464_11120_11248.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__23344_23488_33080_33224.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__50848_51200_25744_26096.png
# The predicted cluster for the image is: 9
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__41560_41688_29328_29456.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__41856_41936_19632_19712.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__11416_11544_12576_12704.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__15888_16080_11072_11264.png
# The predicted cluster for the image is: 6
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__42960_43248_31952_32240.png
# The predicted cluster for the image is: 9
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__9616_9680_20944_21008.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__9504_9600_22336_22432.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__47856_48032_24896_25072.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__6704_6800_23344_23440.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__11904_12080_25280_25456.png
# The predicted cluster for the image is: 7
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__6696_6824_22752_22880.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__48832_49312_19904_20384.png
# The predicted cluster for the image is: 9
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__12944_13040_24760_24856.png
# The predicted cluster for the image is: 7
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__48336_48400_26768_26832.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__49744_49904_27888_28048.png
# The predicted cluster for the image is: 6
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__20936_20968_16000_16032.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__14176_14208_32104_32136.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__14328_14392_24160_24224.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__21096_21384_18688_18976.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__39432_40472_20400_21440.png
# The predicted cluster for the image is: 8
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__44592_45232_34040_34680.png
# The predicted cluster for the image is: 8
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__32496_32960_19880_20344.png
# The predicted cluster for the image is: 5
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__42224_42352_21488_21616.png
# The predicted cluster for the image is: 7
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__37432_38024_16176_16768.png
# The predicted cluster for the image is: 9
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__41856_42160_32096_32400.png
# The predicted cluster for the image is: 5
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__43184_43456_12896_13168.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__30056_30664_24464_25072.png
# The predicted cluster for the image is: 5
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__26016_26048_10760_10792.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__15312_15824_10400_10912.png
# The predicted cluster for the image is: 6
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__49664_49888_26752_26976.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__25296_25632_13584_13920.png
# The predicted cluster for the image is: 9
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__35152_35408_29792_30048.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__43984_44208_21480_21704.png
# The predicted cluster for the image is: 7
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__14864_14976_12856_12968.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__36192_36224_21984_22016.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__14136_14408_31504_31776.png
# The predicted cluster for the image is: 7
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__17160_17320_14784_14944.png
# The predicted cluster for the image is: 7
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__50368_50496_19864_19992.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__15528_15640_33312_33424.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__26528_26880_11184_11536.png
# The predicted cluster for the image is: 9
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__35328_35600_33824_34096.png
# The predicted cluster for the image is: 9
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__26384_26816_15736_16168.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__44160_44272_34224_34336.png
# The predicted cluster for the image is: 7
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__22608_22832_25776_26000.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__47672_48008_20192_20528.png
# The predicted cluster for the image is: 5
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__36384_36656_33320_33592.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__35232_35728_19704_20200.png
# The predicted cluster for the image is: 9
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__20016_20176_31792_31952.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__41536_41984_16456_16904.png
# The predicted cluster for the image is: 7
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__43248_43328_28000_28080.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__38960_39280_31888_32208.png
# The predicted cluster for the image is: 5
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__31440_31504_35672_35736.png
# The predicted cluster for the image is: 3
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__21624_21720_11152_11248.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__50944_51136_25024_25216.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__42072_42248_32784_32960.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__27760_27872_35120_35232.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__9904_10064_16400_16560.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__12048_12128_29112_29192.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__5824_6000_22048_22224.png
# The predicted cluster for the image is: 6
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__38360_38520_25072_25232.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__43904_44160_23360_23616.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__12920_13128_23200_23408.png
# The predicted cluster for the image is: 7
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__37712_37776_32496_32560.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__37152_37248_7984_8080.png
# The predicted cluster for the image is: 4
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__44288_44640_19248_19600.png
# The predicted cluster for the image is: 9
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__46912_47152_21408_21648.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__37808_38240_25584_26016.png
# The predicted cluster for the image is: 9
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__41520_41856_21168_21504.png
# The predicted cluster for the image is: 6
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__32704_32768_15936_16000.png
# The predicted cluster for the image is: 2
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__20304_22160_31408_33264.png
# The predicted cluster for the image is: 5
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__18784_18944_33288_33448.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__19920_20064_10832_10976.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__39856_40016_31016_31176.png
# The predicted cluster for the image is: 7
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__48960_49280_22832_23152.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__27360_27536_11696_11872.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__20600_20888_33504_33792.png
# The predicted cluster for the image is: 5
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__42480_42944_20080_20544.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__32192_32576_21872_22256.png
# The predicted cluster for the image is: 5
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__14336_14704_18048_18416.png
# The predicted cluster for the image is: 7
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__22208_22432_13992_14216.png
# The predicted cluster for the image is: 10
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__31120_34896_25416_29192.png
# The predicted cluster for the image is: 8
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__11896_12056_14960_15120.png
# The predicted cluster for the image is: 7
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs__42208_42304_24592_24688.png
# The predicted cluster for the image is: 1
# TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs_bboxes.png.npy
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[36], line 20
#      18 image_name = os.path.basename(image_path)
#      19 name = image_name.replace('.png','').replace('.svs','').split('__')[0]
# ---> 20 coords_list += [image_name.replace('.png','').replace('.svs','').split('__')[1].split('_')]
#      22 ## Encode the new image to obtain its embedding
#      23 image_embedding = encode_image(image_path, encoder)
#
# IndexError: list index out of range

# %%
###########
## PATHS ##
###########

## Paths
# wsi_paths = ['/Volumes/SED/BDI/databases/RAW/datasets/SEGG/images/train/EU_37106_15_2K_HandE+-+2017-11-28+11.43.55_TissueTrain_(1.00,63062,11375,5880,10230)/reference/EU_37106_15_2K_HandE+-+2017-11-28+11.43.55_TissueTrain_(1.00,63062,11375,5880,10230).png']
# wsi_paths = ['/Volumes/SED/BDI/databases/RAW/datasets/PANDA/images/tiff/0a93d9a674e358ba32e4e2ec320aefc5.tiff'] # PANDA example 1
# wsi_paths = ['/Volumes/SED/BDI/databases/RAW/datasets/PANDA/images/tiff/0bfe4af623f6be66a82289e411320773.tiff'] # PANDA example 2
# wsi_paths = ['/Volumes/SED/BDI/databases/RAW/datasets/TCGA/images/svs/TCGA-EJ-5509-01A_1.svs'] # TCGA
# wsi_paths = '/Volumes/SED/BDI/databases/RAW/datasets/ICGCC/images/svs/TB10.0575_V2_1.svs',
# wsi_paths = '/Volumes/SED/BDI/databases/RAW/datasets/ICGCC/images/svs/TB10.1062_V1_11.svs',
wsi_paths = ['/Volumes/SED/BDI/databases/RAW/datasets/TCGA_FFPE/downloads/ffpes/TCGA-HC-A6AP-01Z-00-DX1.1E2C19B4-6757-488D-AFB4-71AE5FD6EC11.svs']

#
###

# %%
##########################
## GET TILE COORDINATES ##
##########################

## Parameters
TILE_SIZE = 64 # Size of tiles for tissue extraction
FILTER_LOW = 10 # Low filter to remove black tiles
FILTER_HIGH = 240 # High filter to remove white tiles
FILTER_STD = 2 # Std filter to remove grey tiles
WSI_PATH = wsi_paths[0] # Path to WSI

## Open slide
slide = read_slide(WSI_PATH)
slide_size = get_dimensions(slide)

## Get tile_map
thumbnail, tile_map, canvas_size = get_tile_map(slide, TILE_SIZE)

## Get tissue mask
mask = get_tissue_mask(tile_map, FILTER_LOW, FILTER_STD, FILTER_HIGH)

## Get coordinates of tiles with tissue
tile_coordinates = (np.argwhere(mask[:,:,0] > 0) * TILE_SIZE).astype(int)
tile_coordinates = [[tile_coordinate[0], tile_coordinate[1]] for tile_coordinate in tile_coordinates] # (x: H, y: W)

## Compute slide-level tissue mask
tissue_mask = cv2.resize(mask, (canvas_size[1], canvas_size[0]), cv2.INTER_LINEAR)[:,:,None] # (H, W)

#
###

# %%
###################################
## GET TILE COORDINATES - CHECKS ##
###################################

## Compute pixel-tile tissue mask (For checks)
tile_map_masked = tile_map * mask
thumbnail_masked = thumbnail * cv2.resize(mask, (thumbnail.shape[1], thumbnail.shape[0]), cv2.INTER_LINEAR)[:,:,None] # (H, W)

## Visualise mask
fig, axes = plt.subplots(1, 4, figsize=(15, 5))
axes[0].imshow(thumbnail)
axes[1].imshow(tile_map)
axes[2].imshow(tile_map_masked)
axes[3].imshow(thumbnail_masked)
plt.show()
plt.close()

#
###

# %%
###############################
## EXTRACT PATCHES FOR MODEL ##
###############################

## Parameters
LEVEL = 0 # Downsampling level 
TILE_SIZE_MODEL = 1024 # Size of tile for model

## Remove patches too close to the edges
tile_coordinates_thinned = []
for tile_coordinates_ in tile_coordinates:
    coords_0_lo = tile_coordinates_[0] + int(TILE_SIZE/2) - int(TILE_SIZE_MODEL/2)
    coords_0_hi = tile_coordinates_[0] + int(TILE_SIZE/2) + int(TILE_SIZE_MODEL/2)
    coords_1_lo = tile_coordinates_[1] + int(TILE_SIZE/2) - int(TILE_SIZE_MODEL/2)
    coords_1_hi = tile_coordinates_[1] + int(TILE_SIZE/2) + int(TILE_SIZE_MODEL/2)
    if (coords_0_lo > 0) & (coords_0_hi < canvas_size[0]) & (coords_1_lo > 0) & (coords_1_hi < canvas_size[1]):
        tile_coordinates_thinned += [[coords_0_lo, coords_1_lo]]

## Get patches closest to grid points
tile_coordinates_thinned = select_patches_on_grid(tile_coordinates_thinned, grid_spacing=512)

## Load patches from the dataset
patches = slide_path_to_tiles_at_coordinates(WSI_PATH, tile_coordinates_thinned, TILE_SIZE_MODEL, LEVEL) # [dataset[i] for i in range(min(num_patches_to_display, len(dataset)))]
print(f'Number of patches: {len(tile_coordinates_thinned)}')

#
###
# Out:
# Number of patches: 5131

# %%
####################
## REASSEMBLE WSI ##
####################

## Reassemble image
img = reassemble_tiles(patches, tile_coordinates_thinned, canvas_size[0], canvas_size[1])

## Mask
img = img * tissue_mask

#
###

# %%
#############################
## REASSEMBLE WSI - CHECKS ##
#############################

## Format coordinates
coords = np.array(coords_list).astype(int)

## Visualise
fig, axes = plt.subplots(1, 1, figsize=(15, 15))
axes.imshow(img)
x = (coords[:,1] + coords[:,0])//2
y = (coords[:,3] + coords[:,2])//2
s = (np.abs(coords[:,3] - coords[:,2]) + np.abs(coords[:,1] - coords[:,0]))//10
scatter = axes.scatter(y, x, c=cluster_labels, cmap='jet', s=s)
fig.colorbar(scatter, ax=axes, ticks=range(1, 10 + 1), label='Cluster Index')
plt.show()
plt.close()

#
###

# %%
## Visualise
fig, axes = plt.subplots(1, 1, figsize=(15, 15))
axes.imshow(img)
x = (coords[:,1] + coords[:,0])//2
y = (coords[:,3] + coords[:,2])//2
s = (np.abs(coords[:,3] - coords[:,2]) + np.abs(coords[:,1] - coords[:,0]))//10
scatter = axes.scatter(y, x, c=cluster_labels, cmap='jet', s=s)
fig.colorbar(scatter, ax=axes, ticks=range(1, 10 + 1), label='Cluster Index')
plt.show()
plt.close()
