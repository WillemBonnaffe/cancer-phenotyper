# %%
##############
## INITIATE ##
##############

## Import modules
import p_comp2d

#
###

# %%
################
## PARAMETERS ##
################

PT_INPUT_FOLDER = '/Volumes/Elements/BDI/projects/GSG/outputs/o3_mil/tcga-oct/model_resnet_tcgaoct_baseline/'
PATHS_FILE = 'tab_paths.txt'
LABELS_FILE = 'tab_labels.txt'
TILE_SIZE = 256
LEVEL = 0

#
###

# %%
p_comp2d.preprocess_wsi(PT_INPUT_FOLDER, PATHS_FILE, LABELS_FILE, TILE_SIZE, LEVEL)
# Out:
# sample 1/253
# /Volumes/Elements/BDI/datasets/TCGA/images/svs/TCGA-2A-A8VL-01A_1.svs
# tile map created in 0.59s
# sample 2/253
# /Volumes/Elements/BDI/datasets/TCGA/images/svs/TCGA-2A-A8VO-01A_1.svs
# tile map created in 0.60s
# sample 3/253
# /Volumes/Elements/BDI/datasets/TCGA/images/svs/TCGA-2A-A8VT-01A_1.svs
# tile map created in 0.61s
# sample 4/253
# /Volumes/Elements/BDI/datasets/TCGA/images/svs/TCGA-2A-A8VV-01A_1.svs
# tile map created in 0.51s
# sample 5/253
# /Volumes/Elements/BDI/datasets/TCGA/images/svs/TCGA-2A-A8VX-01A_1.svs
# tile map created in 0.51s
# sample 6/253
# /Volumes/Elements/BDI/datasets/TCGA/images/svs/TCGA-2A-A8W1-01A_1.svs
# tile map created in 0.53s
# sample 7/253
# /Volumes/Elements/BDI/datasets/TCGA/images/svs/TCGA-2A-A8W3-01A_1.svs
# tile map created in 0.51s
# sample 8/253
# /Volumes/Elements/BDI/datasets/TCGA/images/svs/TCGA-2A-AAYF-01A_1.svs
# tile map created in 0.55s
# sample 9/253
# ...
