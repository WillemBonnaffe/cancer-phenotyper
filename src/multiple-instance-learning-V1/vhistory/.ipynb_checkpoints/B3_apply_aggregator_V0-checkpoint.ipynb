# %%
##############
## INITIATE ##
##############

## Imports
import os
import numpy as np
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.lines import Line2D

## Import modules
from p_pawmil.m_apply_aggregator import main_apply_aggregator_single

#
###

# %%
##############################
## EVALUATE MULTIPLE MODELS ##
##############################

## Path to main work directory
pwd = "/Users/willembonnaffe/Documents/Academia/Projects/PAW-MIL-2D-PPCG/outputs/PPCG_MQ_SmallMediumNozeroNew_256_MultiTask_Augmented_all/"

## Path to embeddings
pt_embeddings_file = pwd + "encoder/obj_embeddings.pkl"

## Move to aggregator directory
pwd = pwd + "aggregator-1000-singletask/"
hp_star = np.genfromtxt(pwd + "tab_best_hyperparameters.csv", delimiter=",", dtype="str")

## For each label
for hp_star_ in hp_star[1:]: # Skip header

    ## Strip hypertrain metadata
    label, fold, hp = hp_star_    
    bs, ne, lr = str.split(hp, "_")    
    bs = int(float(bs))
    ne = int(float(ne))

    ## Get labels
    pt_labels_file = pwd + f"{label}/tab_labels.txt"        

    ## Path to output
    pt_output_folder = pwd + f"{label}/predictions/"
    if os.path.exists(pt_output_folder) == False:
        os.mkdir(pt_output_folder)
    
    ## For each model
    for val_fold_idx_ in [0, 1, 2, 3, 4]:
        for repeat_idx_ in [0, 1, 2]:
            
            ## Get model id and path to model file
            model_id = f"mod_agg_fold{val_fold_idx_}_repeat{repeat_idx_}_bs{bs}_ne{ne}_lr{lr}"    
            pt_model_file = pwd + f"{label}/hypertrain_fold_{fold}/models/{model_id}.pth"

            ## Output subfolder
            pt_output_folder_ = pt_output_folder + f"{label}_hpt_fold_{fold}_{model_id}/"
            if os.path.exists(pt_output_folder_) == False:
                os.mkdir(pt_output_folder_)

            ## Message 
            print(f"{label}_hpt_fold_{fold}_{model_id}")
            
            ## Apply aggregator
            main_apply_aggregator_single(
                pt_embeddings_file,
                pt_labels_file, 
                pt_model_file,
                pt_output_folder_,
                device = "mps"
                )

#
###
# Out:
# singletask-clinical_risk_index_hpt_fold_1_mod_agg_fold0_repeat0_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.73s
# singletask-clinical_risk_index_hpt_fold_1_mod_agg_fold0_repeat1_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.72s
# singletask-clinical_risk_index_hpt_fold_1_mod_agg_fold0_repeat2_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.70s
# singletask-clinical_risk_index_hpt_fold_1_mod_agg_fold1_repeat0_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.69s
# singletask-clinical_risk_index_hpt_fold_1_mod_agg_fold1_repeat1_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.65s
# singletask-clinical_risk_index_hpt_fold_1_mod_agg_fold1_repeat2_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.68s
# singletask-clinical_risk_index_hpt_fold_1_mod_agg_fold2_repeat0_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.71s
# singletask-clinical_risk_index_hpt_fold_1_mod_agg_fold2_repeat1_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.66s
# singletask-clinical_risk_index_hpt_fold_1_mod_agg_fold2_repeat2_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.69s
# singletask-clinical_risk_index_hpt_fold_1_mod_agg_fold3_repeat0_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.72s
# singletask-clinical_risk_index_hpt_fold_1_mod_agg_fold3_repeat1_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.68s
# singletask-clinical_risk_index_hpt_fold_1_mod_agg_fold3_repeat2_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.79s
# singletask-clinical_risk_index_hpt_fold_1_mod_agg_fold4_repeat0_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.67s
# singletask-clinical_risk_index_hpt_fold_1_mod_agg_fold4_repeat1_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.72s
# singletask-clinical_risk_index_hpt_fold_1_mod_agg_fold4_repeat2_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.67s
# singletask-clinical_risk_index_hpt_fold_2_mod_agg_fold0_repeat0_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.65s
# singletask-clinical_risk_index_hpt_fold_2_mod_agg_fold0_repeat1_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.60s
# singletask-clinical_risk_index_hpt_fold_2_mod_agg_fold0_repeat2_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.60s
# singletask-clinical_risk_index_hpt_fold_2_mod_agg_fold1_repeat0_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.63s
# singletask-clinical_risk_index_hpt_fold_2_mod_agg_fold1_repeat1_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.79s
# singletask-clinical_risk_index_hpt_fold_2_mod_agg_fold1_repeat2_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.64s
# singletask-clinical_risk_index_hpt_fold_2_mod_agg_fold2_repeat0_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.70s
# singletask-clinical_risk_index_hpt_fold_2_mod_agg_fold2_repeat1_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.60s
# singletask-clinical_risk_index_hpt_fold_2_mod_agg_fold2_repeat2_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.57s
# singletask-clinical_risk_index_hpt_fold_2_mod_agg_fold3_repeat0_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.62s
# singletask-clinical_risk_index_hpt_fold_2_mod_agg_fold3_repeat1_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.69s
# singletask-clinical_risk_index_hpt_fold_2_mod_agg_fold3_repeat2_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.71s
# singletask-clinical_risk_index_hpt_fold_2_mod_agg_fold4_repeat0_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.65s
# singletask-clinical_risk_index_hpt_fold_2_mod_agg_fold4_repeat1_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.95s
# singletask-clinical_risk_index_hpt_fold_2_mod_agg_fold4_repeat2_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.99s
# singletask-clinical_risk_index_hpt_fold_3_mod_agg_fold0_repeat0_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.75s
# singletask-clinical_risk_index_hpt_fold_3_mod_agg_fold0_repeat1_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.86s
# singletask-clinical_risk_index_hpt_fold_3_mod_agg_fold0_repeat2_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.96s
# singletask-clinical_risk_index_hpt_fold_3_mod_agg_fold1_repeat0_bs32_ne4_lr0.001/
# loaded model
# generated scores in 4.35s
# singletask-clinical_risk_index_hpt_fold_3_mod_agg_fold1_repeat1_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.71s
# singletask-clinical_risk_index_hpt_fold_3_mod_agg_fold1_repeat2_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.73s
# singletask-clinical_risk_index_hpt_fold_3_mod_agg_fold2_repeat0_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.62s
# singletask-clinical_risk_index_hpt_fold_3_mod_agg_fold2_repeat1_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.76s
# singletask-clinical_risk_index_hpt_fold_3_mod_agg_fold2_repeat2_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.87s
# singletask-clinical_risk_index_hpt_fold_3_mod_agg_fold3_repeat0_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.56s
# singletask-clinical_risk_index_hpt_fold_3_mod_agg_fold3_repeat1_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.58s
# singletask-clinical_risk_index_hpt_fold_3_mod_agg_fold3_repeat2_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.62s
# singletask-clinical_risk_index_hpt_fold_3_mod_agg_fold4_repeat0_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.73s
# singletask-clinical_risk_index_hpt_fold_3_mod_agg_fold4_repeat1_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.64s
# singletask-clinical_risk_index_hpt_fold_3_mod_agg_fold4_repeat2_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.58s
# singletask-clinical_risk_index_hpt_fold_4_mod_agg_fold0_repeat0_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.65s
# singletask-clinical_risk_index_hpt_fold_4_mod_agg_fold0_repeat1_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.77s
# singletask-clinical_risk_index_hpt_fold_4_mod_agg_fold0_repeat2_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.60s
# singletask-clinical_risk_index_hpt_fold_4_mod_agg_fold1_repeat0_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.84s
# singletask-clinical_risk_index_hpt_fold_4_mod_agg_fold1_repeat1_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.63s
# singletask-clinical_risk_index_hpt_fold_4_mod_agg_fold1_repeat2_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.62s
# singletask-clinical_risk_index_hpt_fold_4_mod_agg_fold2_repeat0_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.79s
# singletask-clinical_risk_index_hpt_fold_4_mod_agg_fold2_repeat1_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 4.34s
# singletask-clinical_risk_index_hpt_fold_4_mod_agg_fold2_repeat2_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.67s
# singletask-clinical_risk_index_hpt_fold_4_mod_agg_fold3_repeat0_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.84s
# singletask-clinical_risk_index_hpt_fold_4_mod_agg_fold3_repeat1_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.76s
# singletask-clinical_risk_index_hpt_fold_4_mod_agg_fold3_repeat2_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.71s
# singletask-clinical_risk_index_hpt_fold_4_mod_agg_fold4_repeat0_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.59s
# singletask-clinical_risk_index_hpt_fold_4_mod_agg_fold4_repeat1_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.66s
# singletask-clinical_risk_index_hpt_fold_4_mod_agg_fold4_repeat2_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.61s
# singletask-clinical_risk_index_hpt_fold_5_mod_agg_fold0_repeat0_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.63s
# singletask-clinical_risk_index_hpt_fold_5_mod_agg_fold0_repeat1_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.89s
# singletask-clinical_risk_index_hpt_fold_5_mod_agg_fold0_repeat2_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.77s
# singletask-clinical_risk_index_hpt_fold_5_mod_agg_fold1_repeat0_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.65s
# singletask-clinical_risk_index_hpt_fold_5_mod_agg_fold1_repeat1_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.58s
# singletask-clinical_risk_index_hpt_fold_5_mod_agg_fold1_repeat2_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.59s
# singletask-clinical_risk_index_hpt_fold_5_mod_agg_fold2_repeat0_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.65s
# singletask-clinical_risk_index_hpt_fold_5_mod_agg_fold2_repeat1_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.46s
# singletask-clinical_risk_index_hpt_fold_5_mod_agg_fold2_repeat2_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.58s
# singletask-clinical_risk_index_hpt_fold_5_mod_agg_fold3_repeat0_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.62s
# singletask-clinical_risk_index_hpt_fold_5_mod_agg_fold3_repeat1_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.58s
# singletask-clinical_risk_index_hpt_fold_5_mod_agg_fold3_repeat2_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.58s
# singletask-clinical_risk_index_hpt_fold_5_mod_agg_fold4_repeat0_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.59s
# singletask-clinical_risk_index_hpt_fold_5_mod_agg_fold4_repeat1_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.59s
# singletask-clinical_risk_index_hpt_fold_5_mod_agg_fold4_repeat2_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.63s
# singletask-clinical_lethality_index_hpt_fold_1_mod_agg_fold0_repeat0_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.59s
# singletask-clinical_lethality_index_hpt_fold_1_mod_agg_fold0_repeat1_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.63s
# singletask-clinical_lethality_index_hpt_fold_1_mod_agg_fold0_repeat2_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.61s
# singletask-clinical_lethality_index_hpt_fold_1_mod_agg_fold1_repeat0_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.60s
# singletask-clinical_lethality_index_hpt_fold_1_mod_agg_fold1_repeat1_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.78s
# singletask-clinical_lethality_index_hpt_fold_1_mod_agg_fold1_repeat2_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.58s
# singletask-clinical_lethality_index_hpt_fold_1_mod_agg_fold2_repeat0_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.59s
# singletask-clinical_lethality_index_hpt_fold_1_mod_agg_fold2_repeat1_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.83s
# singletask-clinical_lethality_index_hpt_fold_1_mod_agg_fold2_repeat2_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.61s
# singletask-clinical_lethality_index_hpt_fold_1_mod_agg_fold3_repeat0_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.64s
# singletask-clinical_lethality_index_hpt_fold_1_mod_agg_fold3_repeat1_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.66s
# singletask-clinical_lethality_index_hpt_fold_1_mod_agg_fold3_repeat2_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.62s
# singletask-clinical_lethality_index_hpt_fold_1_mod_agg_fold4_repeat0_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.70s
# singletask-clinical_lethality_index_hpt_fold_1_mod_agg_fold4_repeat1_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.61s
# singletask-clinical_lethality_index_hpt_fold_1_mod_agg_fold4_repeat2_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.63s
# singletask-clinical_lethality_index_hpt_fold_2_mod_agg_fold0_repeat0_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.64s
# singletask-clinical_lethality_index_hpt_fold_2_mod_agg_fold0_repeat1_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.62s
# singletask-clinical_lethality_index_hpt_fold_2_mod_agg_fold0_repeat2_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.58s
# singletask-clinical_lethality_index_hpt_fold_2_mod_agg_fold1_repeat0_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.60s
# singletask-clinical_lethality_index_hpt_fold_2_mod_agg_fold1_repeat1_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.76s
# singletask-clinical_lethality_index_hpt_fold_2_mod_agg_fold1_repeat2_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.58s
# singletask-clinical_lethality_index_hpt_fold_2_mod_agg_fold2_repeat0_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.57s
# singletask-clinical_lethality_index_hpt_fold_2_mod_agg_fold2_repeat1_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.81s
# singletask-clinical_lethality_index_hpt_fold_2_mod_agg_fold2_repeat2_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.60s
# singletask-clinical_lethality_index_hpt_fold_2_mod_agg_fold3_repeat0_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.57s
# singletask-clinical_lethality_index_hpt_fold_2_mod_agg_fold3_repeat1_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.54s
# singletask-clinical_lethality_index_hpt_fold_2_mod_agg_fold3_repeat2_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.74s
# singletask-clinical_lethality_index_hpt_fold_2_mod_agg_fold4_repeat0_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.57s
# singletask-clinical_lethality_index_hpt_fold_2_mod_agg_fold4_repeat1_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.63s
# singletask-clinical_lethality_index_hpt_fold_2_mod_agg_fold4_repeat2_bs32_ne4_lr0.0001/
# loaded model
# generated scores in 3.89s
# singletask-clinical_lethality_index_hpt_fold_3_mod_agg_fold0_repeat0_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.57s
# singletask-clinical_lethality_index_hpt_fold_3_mod_agg_fold0_repeat1_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.60s
# singletask-clinical_lethality_index_hpt_fold_3_mod_agg_fold0_repeat2_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.57s
# singletask-clinical_lethality_index_hpt_fold_3_mod_agg_fold1_repeat0_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.62s
# singletask-clinical_lethality_index_hpt_fold_3_mod_agg_fold1_repeat1_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.56s
# singletask-clinical_lethality_index_hpt_fold_3_mod_agg_fold1_repeat2_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.59s
# singletask-clinical_lethality_index_hpt_fold_3_mod_agg_fold2_repeat0_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.63s
# singletask-clinical_lethality_index_hpt_fold_3_mod_agg_fold2_repeat1_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.76s
# singletask-clinical_lethality_index_hpt_fold_3_mod_agg_fold2_repeat2_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.53s
# singletask-clinical_lethality_index_hpt_fold_3_mod_agg_fold3_repeat0_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.70s
# singletask-clinical_lethality_index_hpt_fold_3_mod_agg_fold3_repeat1_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.55s
# singletask-clinical_lethality_index_hpt_fold_3_mod_agg_fold3_repeat2_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.66s
# singletask-clinical_lethality_index_hpt_fold_3_mod_agg_fold4_repeat0_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.59s
# singletask-clinical_lethality_index_hpt_fold_3_mod_agg_fold4_repeat1_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.57s
# singletask-clinical_lethality_index_hpt_fold_3_mod_agg_fold4_repeat2_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.79s
# singletask-clinical_lethality_index_hpt_fold_4_mod_agg_fold0_repeat0_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.77s
# singletask-clinical_lethality_index_hpt_fold_4_mod_agg_fold0_repeat1_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.59s
# singletask-clinical_lethality_index_hpt_fold_4_mod_agg_fold0_repeat2_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.57s
# singletask-clinical_lethality_index_hpt_fold_4_mod_agg_fold1_repeat0_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.58s
# singletask-clinical_lethality_index_hpt_fold_4_mod_agg_fold1_repeat1_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.59s
# singletask-clinical_lethality_index_hpt_fold_4_mod_agg_fold1_repeat2_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.57s
# singletask-clinical_lethality_index_hpt_fold_4_mod_agg_fold2_repeat0_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.57s
# singletask-clinical_lethality_index_hpt_fold_4_mod_agg_fold2_repeat1_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.56s
# singletask-clinical_lethality_index_hpt_fold_4_mod_agg_fold2_repeat2_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.55s
# singletask-clinical_lethality_index_hpt_fold_4_mod_agg_fold3_repeat0_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.74s
# singletask-clinical_lethality_index_hpt_fold_4_mod_agg_fold3_repeat1_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.57s
# singletask-clinical_lethality_index_hpt_fold_4_mod_agg_fold3_repeat2_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.58s
# singletask-clinical_lethality_index_hpt_fold_4_mod_agg_fold4_repeat0_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.67s
# singletask-clinical_lethality_index_hpt_fold_4_mod_agg_fold4_repeat1_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.81s
# singletask-clinical_lethality_index_hpt_fold_4_mod_agg_fold4_repeat2_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.55s
# singletask-clinical_lethality_index_hpt_fold_5_mod_agg_fold0_repeat0_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.54s
# singletask-clinical_lethality_index_hpt_fold_5_mod_agg_fold0_repeat1_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.57s
# singletask-clinical_lethality_index_hpt_fold_5_mod_agg_fold0_repeat2_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.64s
# singletask-clinical_lethality_index_hpt_fold_5_mod_agg_fold1_repeat0_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.57s
# singletask-clinical_lethality_index_hpt_fold_5_mod_agg_fold1_repeat1_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.76s
# singletask-clinical_lethality_index_hpt_fold_5_mod_agg_fold1_repeat2_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.75s
# singletask-clinical_lethality_index_hpt_fold_5_mod_agg_fold2_repeat0_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.44s
# singletask-clinical_lethality_index_hpt_fold_5_mod_agg_fold2_repeat1_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.51s
# singletask-clinical_lethality_index_hpt_fold_5_mod_agg_fold2_repeat2_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.56s
# singletask-clinical_lethality_index_hpt_fold_5_mod_agg_fold3_repeat0_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.76s
# singletask-clinical_lethality_index_hpt_fold_5_mod_agg_fold3_repeat1_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.58s
# singletask-clinical_lethality_index_hpt_fold_5_mod_agg_fold3_repeat2_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.59s
# singletask-clinical_lethality_index_hpt_fold_5_mod_agg_fold4_repeat0_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.59s
# singletask-clinical_lethality_index_hpt_fold_5_mod_agg_fold4_repeat1_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.72s
# singletask-clinical_lethality_index_hpt_fold_5_mod_agg_fold4_repeat2_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.54s
# singletask-clinical_mets_index_1_hpt_fold_1_mod_agg_fold0_repeat0_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.78s
# singletask-clinical_mets_index_1_hpt_fold_1_mod_agg_fold0_repeat1_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.58s
# singletask-clinical_mets_index_1_hpt_fold_1_mod_agg_fold0_repeat2_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.98s
# singletask-clinical_mets_index_1_hpt_fold_1_mod_agg_fold1_repeat0_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.56s
# singletask-clinical_mets_index_1_hpt_fold_1_mod_agg_fold1_repeat1_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.83s
# singletask-clinical_mets_index_1_hpt_fold_1_mod_agg_fold1_repeat2_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.63s
# singletask-clinical_mets_index_1_hpt_fold_1_mod_agg_fold2_repeat0_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.70s
# singletask-clinical_mets_index_1_hpt_fold_1_mod_agg_fold2_repeat1_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.72s
# singletask-clinical_mets_index_1_hpt_fold_1_mod_agg_fold2_repeat2_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.60s
# singletask-clinical_mets_index_1_hpt_fold_1_mod_agg_fold3_repeat0_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.80s
# singletask-clinical_mets_index_1_hpt_fold_1_mod_agg_fold3_repeat1_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.67s
# singletask-clinical_mets_index_1_hpt_fold_1_mod_agg_fold3_repeat2_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.60s
# singletask-clinical_mets_index_1_hpt_fold_1_mod_agg_fold4_repeat0_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.78s
# singletask-clinical_mets_index_1_hpt_fold_1_mod_agg_fold4_repeat1_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.59s
# singletask-clinical_mets_index_1_hpt_fold_1_mod_agg_fold4_repeat2_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.60s
# singletask-clinical_mets_index_1_hpt_fold_2_mod_agg_fold0_repeat0_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.76s
# singletask-clinical_mets_index_1_hpt_fold_2_mod_agg_fold0_repeat1_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.61s
# singletask-clinical_mets_index_1_hpt_fold_2_mod_agg_fold0_repeat2_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.58s
# singletask-clinical_mets_index_1_hpt_fold_2_mod_agg_fold1_repeat0_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.62s
# singletask-clinical_mets_index_1_hpt_fold_2_mod_agg_fold1_repeat1_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.57s
# singletask-clinical_mets_index_1_hpt_fold_2_mod_agg_fold1_repeat2_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.71s
# singletask-clinical_mets_index_1_hpt_fold_2_mod_agg_fold2_repeat0_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.65s
# singletask-clinical_mets_index_1_hpt_fold_2_mod_agg_fold2_repeat1_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.70s
# singletask-clinical_mets_index_1_hpt_fold_2_mod_agg_fold2_repeat2_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.57s
# singletask-clinical_mets_index_1_hpt_fold_2_mod_agg_fold3_repeat0_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.82s
# singletask-clinical_mets_index_1_hpt_fold_2_mod_agg_fold3_repeat1_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.74s
# singletask-clinical_mets_index_1_hpt_fold_2_mod_agg_fold3_repeat2_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.61s
# singletask-clinical_mets_index_1_hpt_fold_2_mod_agg_fold4_repeat0_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.67s
# singletask-clinical_mets_index_1_hpt_fold_2_mod_agg_fold4_repeat1_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.54s
# singletask-clinical_mets_index_1_hpt_fold_2_mod_agg_fold4_repeat2_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.57s
# singletask-clinical_mets_index_1_hpt_fold_3_mod_agg_fold0_repeat0_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.74s
# singletask-clinical_mets_index_1_hpt_fold_3_mod_agg_fold0_repeat1_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.72s
# singletask-clinical_mets_index_1_hpt_fold_3_mod_agg_fold0_repeat2_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.69s
# singletask-clinical_mets_index_1_hpt_fold_3_mod_agg_fold1_repeat0_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.58s
# singletask-clinical_mets_index_1_hpt_fold_3_mod_agg_fold1_repeat1_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.67s
# singletask-clinical_mets_index_1_hpt_fold_3_mod_agg_fold1_repeat2_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.76s
# singletask-clinical_mets_index_1_hpt_fold_3_mod_agg_fold2_repeat0_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.60s
# singletask-clinical_mets_index_1_hpt_fold_3_mod_agg_fold2_repeat1_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.70s
# singletask-clinical_mets_index_1_hpt_fold_3_mod_agg_fold2_repeat2_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.58s
# singletask-clinical_mets_index_1_hpt_fold_3_mod_agg_fold3_repeat0_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.58s
# singletask-clinical_mets_index_1_hpt_fold_3_mod_agg_fold3_repeat1_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.60s
# singletask-clinical_mets_index_1_hpt_fold_3_mod_agg_fold3_repeat2_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.59s
# singletask-clinical_mets_index_1_hpt_fold_3_mod_agg_fold4_repeat0_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.58s
# singletask-clinical_mets_index_1_hpt_fold_3_mod_agg_fold4_repeat1_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.79s
# singletask-clinical_mets_index_1_hpt_fold_3_mod_agg_fold4_repeat2_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.87s
# singletask-clinical_mets_index_1_hpt_fold_4_mod_agg_fold0_repeat0_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.66s
# singletask-clinical_mets_index_1_hpt_fold_4_mod_agg_fold0_repeat1_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.60s
# singletask-clinical_mets_index_1_hpt_fold_4_mod_agg_fold0_repeat2_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.61s
# singletask-clinical_mets_index_1_hpt_fold_4_mod_agg_fold1_repeat0_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.59s
# singletask-clinical_mets_index_1_hpt_fold_4_mod_agg_fold1_repeat1_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.68s
# singletask-clinical_mets_index_1_hpt_fold_4_mod_agg_fold1_repeat2_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.90s
# singletask-clinical_mets_index_1_hpt_fold_4_mod_agg_fold2_repeat0_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.76s
# singletask-clinical_mets_index_1_hpt_fold_4_mod_agg_fold2_repeat1_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.70s
# singletask-clinical_mets_index_1_hpt_fold_4_mod_agg_fold2_repeat2_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.57s
# singletask-clinical_mets_index_1_hpt_fold_4_mod_agg_fold3_repeat0_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.57s
# singletask-clinical_mets_index_1_hpt_fold_4_mod_agg_fold3_repeat1_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.68s
# singletask-clinical_mets_index_1_hpt_fold_4_mod_agg_fold3_repeat2_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.78s
# singletask-clinical_mets_index_1_hpt_fold_4_mod_agg_fold4_repeat0_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.64s
# singletask-clinical_mets_index_1_hpt_fold_4_mod_agg_fold4_repeat1_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.78s
# singletask-clinical_mets_index_1_hpt_fold_4_mod_agg_fold4_repeat2_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.90s
# singletask-clinical_mets_index_1_hpt_fold_5_mod_agg_fold0_repeat0_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.87s
# singletask-clinical_mets_index_1_hpt_fold_5_mod_agg_fold0_repeat1_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.60s
# singletask-clinical_mets_index_1_hpt_fold_5_mod_agg_fold0_repeat2_bs64_ne8_lr0.001/
# loaded model
# generated scores in 4.19s
# singletask-clinical_mets_index_1_hpt_fold_5_mod_agg_fold1_repeat0_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.99s
# singletask-clinical_mets_index_1_hpt_fold_5_mod_agg_fold1_repeat1_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.80s
# singletask-clinical_mets_index_1_hpt_fold_5_mod_agg_fold1_repeat2_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.62s
# singletask-clinical_mets_index_1_hpt_fold_5_mod_agg_fold2_repeat0_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.68s
# singletask-clinical_mets_index_1_hpt_fold_5_mod_agg_fold2_repeat1_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.95s
# singletask-clinical_mets_index_1_hpt_fold_5_mod_agg_fold2_repeat2_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.59s
# singletask-clinical_mets_index_1_hpt_fold_5_mod_agg_fold3_repeat0_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.60s
# singletask-clinical_mets_index_1_hpt_fold_5_mod_agg_fold3_repeat1_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.60s
# singletask-clinical_mets_index_1_hpt_fold_5_mod_agg_fold3_repeat2_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.60s
# singletask-clinical_mets_index_1_hpt_fold_5_mod_agg_fold4_repeat0_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.96s
# singletask-clinical_mets_index_1_hpt_fold_5_mod_agg_fold4_repeat1_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.60s
# singletask-clinical_mets_index_1_hpt_fold_5_mod_agg_fold4_repeat2_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.60s
# singletask-clinical_mets_index_2_hpt_fold_1_mod_agg_fold0_repeat0_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.61s
# singletask-clinical_mets_index_2_hpt_fold_1_mod_agg_fold0_repeat1_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.60s
# singletask-clinical_mets_index_2_hpt_fold_1_mod_agg_fold0_repeat2_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.66s
# singletask-clinical_mets_index_2_hpt_fold_1_mod_agg_fold1_repeat0_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.61s
# singletask-clinical_mets_index_2_hpt_fold_1_mod_agg_fold1_repeat1_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.64s
# singletask-clinical_mets_index_2_hpt_fold_1_mod_agg_fold1_repeat2_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.59s
# singletask-clinical_mets_index_2_hpt_fold_1_mod_agg_fold2_repeat0_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.70s
# singletask-clinical_mets_index_2_hpt_fold_1_mod_agg_fold2_repeat1_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.69s
# singletask-clinical_mets_index_2_hpt_fold_1_mod_agg_fold2_repeat2_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.62s
# singletask-clinical_mets_index_2_hpt_fold_1_mod_agg_fold3_repeat0_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.67s
# singletask-clinical_mets_index_2_hpt_fold_1_mod_agg_fold3_repeat1_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.64s
# singletask-clinical_mets_index_2_hpt_fold_1_mod_agg_fold3_repeat2_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.80s
# singletask-clinical_mets_index_2_hpt_fold_1_mod_agg_fold4_repeat0_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.60s
# singletask-clinical_mets_index_2_hpt_fold_1_mod_agg_fold4_repeat1_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.65s
# singletask-clinical_mets_index_2_hpt_fold_1_mod_agg_fold4_repeat2_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.85s
# singletask-clinical_mets_index_2_hpt_fold_2_mod_agg_fold0_repeat0_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.77s
# singletask-clinical_mets_index_2_hpt_fold_2_mod_agg_fold0_repeat1_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.74s
# singletask-clinical_mets_index_2_hpt_fold_2_mod_agg_fold0_repeat2_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.64s
# singletask-clinical_mets_index_2_hpt_fold_2_mod_agg_fold1_repeat0_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.80s
# singletask-clinical_mets_index_2_hpt_fold_2_mod_agg_fold1_repeat1_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.57s
# singletask-clinical_mets_index_2_hpt_fold_2_mod_agg_fold1_repeat2_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.57s
# singletask-clinical_mets_index_2_hpt_fold_2_mod_agg_fold2_repeat0_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.79s
# singletask-clinical_mets_index_2_hpt_fold_2_mod_agg_fold2_repeat1_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.74s
# singletask-clinical_mets_index_2_hpt_fold_2_mod_agg_fold2_repeat2_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.61s
# singletask-clinical_mets_index_2_hpt_fold_2_mod_agg_fold3_repeat0_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.60s
# singletask-clinical_mets_index_2_hpt_fold_2_mod_agg_fold3_repeat1_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.59s
# singletask-clinical_mets_index_2_hpt_fold_2_mod_agg_fold3_repeat2_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.57s
# singletask-clinical_mets_index_2_hpt_fold_2_mod_agg_fold4_repeat0_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.58s
# singletask-clinical_mets_index_2_hpt_fold_2_mod_agg_fold4_repeat1_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.64s
# singletask-clinical_mets_index_2_hpt_fold_2_mod_agg_fold4_repeat2_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.55s
# singletask-clinical_mets_index_2_hpt_fold_3_mod_agg_fold0_repeat0_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.63s
# singletask-clinical_mets_index_2_hpt_fold_3_mod_agg_fold0_repeat1_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.93s
# singletask-clinical_mets_index_2_hpt_fold_3_mod_agg_fold0_repeat2_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.68s
# singletask-clinical_mets_index_2_hpt_fold_3_mod_agg_fold1_repeat0_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.78s
# singletask-clinical_mets_index_2_hpt_fold_3_mod_agg_fold1_repeat1_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.89s
# singletask-clinical_mets_index_2_hpt_fold_3_mod_agg_fold1_repeat2_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.85s
# singletask-clinical_mets_index_2_hpt_fold_3_mod_agg_fold2_repeat0_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.66s
# singletask-clinical_mets_index_2_hpt_fold_3_mod_agg_fold2_repeat1_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.63s
# singletask-clinical_mets_index_2_hpt_fold_3_mod_agg_fold2_repeat2_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.76s
# singletask-clinical_mets_index_2_hpt_fold_3_mod_agg_fold3_repeat0_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.63s
# singletask-clinical_mets_index_2_hpt_fold_3_mod_agg_fold3_repeat1_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.59s
# singletask-clinical_mets_index_2_hpt_fold_3_mod_agg_fold3_repeat2_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.65s
# singletask-clinical_mets_index_2_hpt_fold_3_mod_agg_fold4_repeat0_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.78s
# singletask-clinical_mets_index_2_hpt_fold_3_mod_agg_fold4_repeat1_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.61s
# singletask-clinical_mets_index_2_hpt_fold_3_mod_agg_fold4_repeat2_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.85s
# singletask-clinical_mets_index_2_hpt_fold_4_mod_agg_fold0_repeat0_bs32_ne8_lr0.001/
# loaded model
# generated scores in 4.11s
# singletask-clinical_mets_index_2_hpt_fold_4_mod_agg_fold0_repeat1_bs32_ne8_lr0.001/
# loaded model
# generated scores in 4.35s
# singletask-clinical_mets_index_2_hpt_fold_4_mod_agg_fold0_repeat2_bs32_ne8_lr0.001/
# loaded model
# generated scores in 4.23s
# singletask-clinical_mets_index_2_hpt_fold_4_mod_agg_fold1_repeat0_bs32_ne8_lr0.001/
# loaded model
# generated scores in 4.87s
# singletask-clinical_mets_index_2_hpt_fold_4_mod_agg_fold1_repeat1_bs32_ne8_lr0.001/
# loaded model
# generated scores in 5.21s
# singletask-clinical_mets_index_2_hpt_fold_4_mod_agg_fold1_repeat2_bs32_ne8_lr0.001/
# loaded model
# generated scores in 4.53s
# singletask-clinical_mets_index_2_hpt_fold_4_mod_agg_fold2_repeat0_bs32_ne8_lr0.001/
# loaded model
# generated scores in 4.66s
# singletask-clinical_mets_index_2_hpt_fold_4_mod_agg_fold2_repeat1_bs32_ne8_lr0.001/
# loaded model
# generated scores in 4.57s
# singletask-clinical_mets_index_2_hpt_fold_4_mod_agg_fold2_repeat2_bs32_ne8_lr0.001/
# loaded model
# generated scores in 4.83s
# singletask-clinical_mets_index_2_hpt_fold_4_mod_agg_fold3_repeat0_bs32_ne8_lr0.001/
# loaded model
# generated scores in 4.67s
# singletask-clinical_mets_index_2_hpt_fold_4_mod_agg_fold3_repeat1_bs32_ne8_lr0.001/
# loaded model
# generated scores in 4.87s
# singletask-clinical_mets_index_2_hpt_fold_4_mod_agg_fold3_repeat2_bs32_ne8_lr0.001/
# loaded model
# generated scores in 4.87s
# singletask-clinical_mets_index_2_hpt_fold_4_mod_agg_fold4_repeat0_bs32_ne8_lr0.001/
# loaded model
# generated scores in 4.82s
# singletask-clinical_mets_index_2_hpt_fold_4_mod_agg_fold4_repeat1_bs32_ne8_lr0.001/
# loaded model
# generated scores in 4.65s
# singletask-clinical_mets_index_2_hpt_fold_4_mod_agg_fold4_repeat2_bs32_ne8_lr0.001/
# loaded model
# generated scores in 4.56s
# singletask-clinical_mets_index_2_hpt_fold_5_mod_agg_fold0_repeat0_bs64_ne8_lr0.001/
# loaded model
# generated scores in 4.80s
# singletask-clinical_mets_index_2_hpt_fold_5_mod_agg_fold0_repeat1_bs64_ne8_lr0.001/
# loaded model
# generated scores in 4.01s
# singletask-clinical_mets_index_2_hpt_fold_5_mod_agg_fold0_repeat2_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.76s
# singletask-clinical_mets_index_2_hpt_fold_5_mod_agg_fold1_repeat0_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.64s
# singletask-clinical_mets_index_2_hpt_fold_5_mod_agg_fold1_repeat1_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.75s
# singletask-clinical_mets_index_2_hpt_fold_5_mod_agg_fold1_repeat2_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.63s
# singletask-clinical_mets_index_2_hpt_fold_5_mod_agg_fold2_repeat0_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.61s
# singletask-clinical_mets_index_2_hpt_fold_5_mod_agg_fold2_repeat1_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.62s
# singletask-clinical_mets_index_2_hpt_fold_5_mod_agg_fold2_repeat2_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.59s
# singletask-clinical_mets_index_2_hpt_fold_5_mod_agg_fold3_repeat0_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.71s
# singletask-clinical_mets_index_2_hpt_fold_5_mod_agg_fold3_repeat1_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.64s
# singletask-clinical_mets_index_2_hpt_fold_5_mod_agg_fold3_repeat2_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.60s
# singletask-clinical_mets_index_2_hpt_fold_5_mod_agg_fold4_repeat0_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.60s
# singletask-clinical_mets_index_2_hpt_fold_5_mod_agg_fold4_repeat1_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.73s
# singletask-clinical_mets_index_2_hpt_fold_5_mod_agg_fold4_repeat2_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.76s
# singletask-clinical_gleason_index_1_hpt_fold_1_mod_agg_fold0_repeat0_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.62s
# singletask-clinical_gleason_index_1_hpt_fold_1_mod_agg_fold0_repeat1_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.81s
# singletask-clinical_gleason_index_1_hpt_fold_1_mod_agg_fold0_repeat2_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.63s
# singletask-clinical_gleason_index_1_hpt_fold_1_mod_agg_fold1_repeat0_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.62s
# singletask-clinical_gleason_index_1_hpt_fold_1_mod_agg_fold1_repeat1_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.64s
# singletask-clinical_gleason_index_1_hpt_fold_1_mod_agg_fold1_repeat2_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.62s
# singletask-clinical_gleason_index_1_hpt_fold_1_mod_agg_fold2_repeat0_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.58s
# singletask-clinical_gleason_index_1_hpt_fold_1_mod_agg_fold2_repeat1_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.57s
# singletask-clinical_gleason_index_1_hpt_fold_1_mod_agg_fold2_repeat2_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.58s
# singletask-clinical_gleason_index_1_hpt_fold_1_mod_agg_fold3_repeat0_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.58s
# singletask-clinical_gleason_index_1_hpt_fold_1_mod_agg_fold3_repeat1_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.59s
# singletask-clinical_gleason_index_1_hpt_fold_1_mod_agg_fold3_repeat2_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.76s
# singletask-clinical_gleason_index_1_hpt_fold_1_mod_agg_fold4_repeat0_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.71s
# singletask-clinical_gleason_index_1_hpt_fold_1_mod_agg_fold4_repeat1_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.78s
# singletask-clinical_gleason_index_1_hpt_fold_1_mod_agg_fold4_repeat2_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.98s
# singletask-clinical_gleason_index_1_hpt_fold_2_mod_agg_fold0_repeat0_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.89s
# singletask-clinical_gleason_index_1_hpt_fold_2_mod_agg_fold0_repeat1_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.67s
# singletask-clinical_gleason_index_1_hpt_fold_2_mod_agg_fold0_repeat2_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.77s
# singletask-clinical_gleason_index_1_hpt_fold_2_mod_agg_fold1_repeat0_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.60s
# singletask-clinical_gleason_index_1_hpt_fold_2_mod_agg_fold1_repeat1_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.90s
# singletask-clinical_gleason_index_1_hpt_fold_2_mod_agg_fold1_repeat2_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.81s
# singletask-clinical_gleason_index_1_hpt_fold_2_mod_agg_fold2_repeat0_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 4.01s
# singletask-clinical_gleason_index_1_hpt_fold_2_mod_agg_fold2_repeat1_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.63s
# singletask-clinical_gleason_index_1_hpt_fold_2_mod_agg_fold2_repeat2_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.64s
# singletask-clinical_gleason_index_1_hpt_fold_2_mod_agg_fold3_repeat0_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.78s
# singletask-clinical_gleason_index_1_hpt_fold_2_mod_agg_fold3_repeat1_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.57s
# singletask-clinical_gleason_index_1_hpt_fold_2_mod_agg_fold3_repeat2_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.64s
# singletask-clinical_gleason_index_1_hpt_fold_2_mod_agg_fold4_repeat0_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.64s
# singletask-clinical_gleason_index_1_hpt_fold_2_mod_agg_fold4_repeat1_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.59s
# singletask-clinical_gleason_index_1_hpt_fold_2_mod_agg_fold4_repeat2_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.56s
# singletask-clinical_gleason_index_1_hpt_fold_3_mod_agg_fold0_repeat0_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.83s
# singletask-clinical_gleason_index_1_hpt_fold_3_mod_agg_fold0_repeat1_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.85s
# singletask-clinical_gleason_index_1_hpt_fold_3_mod_agg_fold0_repeat2_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.71s
# singletask-clinical_gleason_index_1_hpt_fold_3_mod_agg_fold1_repeat0_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.64s
# singletask-clinical_gleason_index_1_hpt_fold_3_mod_agg_fold1_repeat1_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.60s
# singletask-clinical_gleason_index_1_hpt_fold_3_mod_agg_fold1_repeat2_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.67s
# singletask-clinical_gleason_index_1_hpt_fold_3_mod_agg_fold2_repeat0_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.76s
# singletask-clinical_gleason_index_1_hpt_fold_3_mod_agg_fold2_repeat1_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.84s
# singletask-clinical_gleason_index_1_hpt_fold_3_mod_agg_fold2_repeat2_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.90s
# singletask-clinical_gleason_index_1_hpt_fold_3_mod_agg_fold3_repeat0_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.60s
# singletask-clinical_gleason_index_1_hpt_fold_3_mod_agg_fold3_repeat1_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.62s
# singletask-clinical_gleason_index_1_hpt_fold_3_mod_agg_fold3_repeat2_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.83s
# singletask-clinical_gleason_index_1_hpt_fold_3_mod_agg_fold4_repeat0_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.67s
# singletask-clinical_gleason_index_1_hpt_fold_3_mod_agg_fold4_repeat1_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.77s
# singletask-clinical_gleason_index_1_hpt_fold_3_mod_agg_fold4_repeat2_bs64_ne8_lr0.001/
# loaded model
# generated scores in 3.72s
# singletask-clinical_gleason_index_1_hpt_fold_4_mod_agg_fold0_repeat0_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.83s
# singletask-clinical_gleason_index_1_hpt_fold_4_mod_agg_fold0_repeat1_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.61s
# singletask-clinical_gleason_index_1_hpt_fold_4_mod_agg_fold0_repeat2_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.62s
# singletask-clinical_gleason_index_1_hpt_fold_4_mod_agg_fold1_repeat0_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.56s
# singletask-clinical_gleason_index_1_hpt_fold_4_mod_agg_fold1_repeat1_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.55s
# singletask-clinical_gleason_index_1_hpt_fold_4_mod_agg_fold1_repeat2_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.64s
# singletask-clinical_gleason_index_1_hpt_fold_4_mod_agg_fold2_repeat0_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.57s
# singletask-clinical_gleason_index_1_hpt_fold_4_mod_agg_fold2_repeat1_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.62s
# singletask-clinical_gleason_index_1_hpt_fold_4_mod_agg_fold2_repeat2_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.82s
# singletask-clinical_gleason_index_1_hpt_fold_4_mod_agg_fold3_repeat0_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.62s
# singletask-clinical_gleason_index_1_hpt_fold_4_mod_agg_fold3_repeat1_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.56s
# singletask-clinical_gleason_index_1_hpt_fold_4_mod_agg_fold3_repeat2_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.87s
# singletask-clinical_gleason_index_1_hpt_fold_4_mod_agg_fold4_repeat0_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.82s
# singletask-clinical_gleason_index_1_hpt_fold_4_mod_agg_fold4_repeat1_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.89s
# singletask-clinical_gleason_index_1_hpt_fold_4_mod_agg_fold4_repeat2_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.83s
# singletask-clinical_gleason_index_1_hpt_fold_5_mod_agg_fold0_repeat0_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.58s
# singletask-clinical_gleason_index_1_hpt_fold_5_mod_agg_fold0_repeat1_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.81s
# singletask-clinical_gleason_index_1_hpt_fold_5_mod_agg_fold0_repeat2_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.60s
# singletask-clinical_gleason_index_1_hpt_fold_5_mod_agg_fold1_repeat0_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.70s
# singletask-clinical_gleason_index_1_hpt_fold_5_mod_agg_fold1_repeat1_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.71s
# singletask-clinical_gleason_index_1_hpt_fold_5_mod_agg_fold1_repeat2_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.66s
# singletask-clinical_gleason_index_1_hpt_fold_5_mod_agg_fold2_repeat0_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.79s
# singletask-clinical_gleason_index_1_hpt_fold_5_mod_agg_fold2_repeat1_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.81s
# singletask-clinical_gleason_index_1_hpt_fold_5_mod_agg_fold2_repeat2_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.89s
# singletask-clinical_gleason_index_1_hpt_fold_5_mod_agg_fold3_repeat0_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.83s
# singletask-clinical_gleason_index_1_hpt_fold_5_mod_agg_fold3_repeat1_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.59s
# singletask-clinical_gleason_index_1_hpt_fold_5_mod_agg_fold3_repeat2_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.65s
# singletask-clinical_gleason_index_1_hpt_fold_5_mod_agg_fold4_repeat0_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.64s
# singletask-clinical_gleason_index_1_hpt_fold_5_mod_agg_fold4_repeat1_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.63s
# singletask-clinical_gleason_index_1_hpt_fold_5_mod_agg_fold4_repeat2_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.58s
# singletask-clinical_gleason_index_2_hpt_fold_1_mod_agg_fold0_repeat0_bs64_ne4_lr0.001/
# loaded model
# generated scores in 3.57s
# singletask-clinical_gleason_index_2_hpt_fold_1_mod_agg_fold0_repeat1_bs64_ne4_lr0.001/
# loaded model
# generated scores in 3.73s
# singletask-clinical_gleason_index_2_hpt_fold_1_mod_agg_fold0_repeat2_bs64_ne4_lr0.001/
# loaded model
# generated scores in 3.84s
# singletask-clinical_gleason_index_2_hpt_fold_1_mod_agg_fold1_repeat0_bs64_ne4_lr0.001/
# loaded model
# generated scores in 3.60s
# singletask-clinical_gleason_index_2_hpt_fold_1_mod_agg_fold1_repeat1_bs64_ne4_lr0.001/
# loaded model
# generated scores in 3.73s
# singletask-clinical_gleason_index_2_hpt_fold_1_mod_agg_fold1_repeat2_bs64_ne4_lr0.001/
# loaded model
# generated scores in 3.76s
# singletask-clinical_gleason_index_2_hpt_fold_1_mod_agg_fold2_repeat0_bs64_ne4_lr0.001/
# loaded model
# generated scores in 3.62s
# singletask-clinical_gleason_index_2_hpt_fold_1_mod_agg_fold2_repeat1_bs64_ne4_lr0.001/
# loaded model
# generated scores in 3.67s
# singletask-clinical_gleason_index_2_hpt_fold_1_mod_agg_fold2_repeat2_bs64_ne4_lr0.001/
# loaded model
# generated scores in 3.81s
# singletask-clinical_gleason_index_2_hpt_fold_1_mod_agg_fold3_repeat0_bs64_ne4_lr0.001/
# loaded model
# generated scores in 3.74s
# singletask-clinical_gleason_index_2_hpt_fold_1_mod_agg_fold3_repeat1_bs64_ne4_lr0.001/
# loaded model
# generated scores in 3.78s
# ...
# singletask-events_LOH.18.22010421.78011583_hpt_fold_3_mod_agg_fold0_repeat0_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.83s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_3_mod_agg_fold0_repeat1_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.77s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_3_mod_agg_fold0_repeat2_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.70s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_3_mod_agg_fold1_repeat0_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.69s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_3_mod_agg_fold1_repeat1_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.90s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_3_mod_agg_fold1_repeat2_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.72s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_3_mod_agg_fold2_repeat0_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.79s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_3_mod_agg_fold2_repeat1_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 4.09s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_3_mod_agg_fold2_repeat2_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.77s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_3_mod_agg_fold3_repeat0_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.68s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_3_mod_agg_fold3_repeat1_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.81s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_3_mod_agg_fold3_repeat2_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.65s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_3_mod_agg_fold4_repeat0_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 4.10s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_3_mod_agg_fold4_repeat1_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.90s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_3_mod_agg_fold4_repeat2_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.70s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_4_mod_agg_fold0_repeat0_bs32_ne8_lr0.0001/
# loaded model
# generated scores in 3.74s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_4_mod_agg_fold0_repeat1_bs32_ne8_lr0.0001/
# loaded model
# generated scores in 3.81s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_4_mod_agg_fold0_repeat2_bs32_ne8_lr0.0001/
# loaded model
# generated scores in 3.91s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_4_mod_agg_fold1_repeat0_bs32_ne8_lr0.0001/
# loaded model
# generated scores in 3.66s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_4_mod_agg_fold1_repeat1_bs32_ne8_lr0.0001/
# loaded model
# generated scores in 3.91s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_4_mod_agg_fold1_repeat2_bs32_ne8_lr0.0001/
# loaded model
# generated scores in 3.87s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_4_mod_agg_fold2_repeat0_bs32_ne8_lr0.0001/
# loaded model
# generated scores in 3.79s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_4_mod_agg_fold2_repeat1_bs32_ne8_lr0.0001/
# loaded model
# generated scores in 3.65s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_4_mod_agg_fold2_repeat2_bs32_ne8_lr0.0001/
# loaded model
# generated scores in 3.73s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_4_mod_agg_fold3_repeat0_bs32_ne8_lr0.0001/
# loaded model
# generated scores in 3.76s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_4_mod_agg_fold3_repeat1_bs32_ne8_lr0.0001/
# loaded model
# generated scores in 3.82s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_4_mod_agg_fold3_repeat2_bs32_ne8_lr0.0001/
# loaded model
# generated scores in 3.79s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_4_mod_agg_fold4_repeat0_bs32_ne8_lr0.0001/
# loaded model
# generated scores in 3.80s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_4_mod_agg_fold4_repeat1_bs32_ne8_lr0.0001/
# loaded model
# generated scores in 3.79s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_4_mod_agg_fold4_repeat2_bs32_ne8_lr0.0001/
# loaded model
# generated scores in 3.80s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_5_mod_agg_fold0_repeat0_bs32_ne8_lr0.0001/
# loaded model
# generated scores in 3.80s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_5_mod_agg_fold0_repeat1_bs32_ne8_lr0.0001/
# loaded model
# generated scores in 4.00s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_5_mod_agg_fold0_repeat2_bs32_ne8_lr0.0001/
# loaded model
# generated scores in 3.82s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_5_mod_agg_fold1_repeat0_bs32_ne8_lr0.0001/
# loaded model
# generated scores in 3.67s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_5_mod_agg_fold1_repeat1_bs32_ne8_lr0.0001/
# loaded model
# generated scores in 3.77s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_5_mod_agg_fold1_repeat2_bs32_ne8_lr0.0001/
# loaded model
# generated scores in 3.67s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_5_mod_agg_fold2_repeat0_bs32_ne8_lr0.0001/
# loaded model
# generated scores in 3.93s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_5_mod_agg_fold2_repeat1_bs32_ne8_lr0.0001/
# loaded model
# generated scores in 3.99s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_5_mod_agg_fold2_repeat2_bs32_ne8_lr0.0001/
# loaded model
# generated scores in 3.93s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_5_mod_agg_fold3_repeat0_bs32_ne8_lr0.0001/
# loaded model
# generated scores in 3.79s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_5_mod_agg_fold3_repeat1_bs32_ne8_lr0.0001/
# loaded model
# generated scores in 3.65s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_5_mod_agg_fold3_repeat2_bs32_ne8_lr0.0001/
# loaded model
# generated scores in 3.76s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_5_mod_agg_fold4_repeat0_bs32_ne8_lr0.0001/
# loaded model
# generated scores in 3.76s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_5_mod_agg_fold4_repeat1_bs32_ne8_lr0.0001/
# loaded model
# generated scores in 3.79s
# singletask-events_LOH.18.22010421.78011583_hpt_fold_5_mod_agg_fold4_repeat2_bs32_ne8_lr0.0001/
# loaded model
# generated scores in 3.63s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_1_mod_agg_fold0_repeat0_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.80s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_1_mod_agg_fold0_repeat1_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.72s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_1_mod_agg_fold0_repeat2_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.80s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_1_mod_agg_fold1_repeat0_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.74s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_1_mod_agg_fold1_repeat1_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.70s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_1_mod_agg_fold1_repeat2_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.73s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_1_mod_agg_fold2_repeat0_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.76s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_1_mod_agg_fold2_repeat1_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.74s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_1_mod_agg_fold2_repeat2_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.80s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_1_mod_agg_fold3_repeat0_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.81s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_1_mod_agg_fold3_repeat1_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.87s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_1_mod_agg_fold3_repeat2_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.88s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_1_mod_agg_fold4_repeat0_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.80s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_1_mod_agg_fold4_repeat1_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.82s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_1_mod_agg_fold4_repeat2_bs32_ne4_lr0.001/
# loaded model
# generated scores in 3.79s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_2_mod_agg_fold0_repeat0_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.69s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_2_mod_agg_fold0_repeat1_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.83s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_2_mod_agg_fold0_repeat2_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.78s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_2_mod_agg_fold1_repeat0_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.65s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_2_mod_agg_fold1_repeat1_bs32_ne8_lr0.001/
# loaded model
# generated scores in 4.02s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_2_mod_agg_fold1_repeat2_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.99s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_2_mod_agg_fold2_repeat0_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.89s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_2_mod_agg_fold2_repeat1_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.79s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_2_mod_agg_fold2_repeat2_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.77s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_2_mod_agg_fold3_repeat0_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.90s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_2_mod_agg_fold3_repeat1_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.71s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_2_mod_agg_fold3_repeat2_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.91s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_2_mod_agg_fold4_repeat0_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.87s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_2_mod_agg_fold4_repeat1_bs32_ne8_lr0.001/
# loaded model
# generated scores in 3.87s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_2_mod_agg_fold4_repeat2_bs32_ne8_lr0.001/
# loaded model
# generated scores in 4.07s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_3_mod_agg_fold0_repeat0_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.85s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_3_mod_agg_fold0_repeat1_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.89s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_3_mod_agg_fold0_repeat2_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.94s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_3_mod_agg_fold1_repeat0_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.77s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_3_mod_agg_fold1_repeat1_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.82s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_3_mod_agg_fold1_repeat2_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.80s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_3_mod_agg_fold2_repeat0_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.90s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_3_mod_agg_fold2_repeat1_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.87s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_3_mod_agg_fold2_repeat2_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.82s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_3_mod_agg_fold3_repeat0_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.98s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_3_mod_agg_fold3_repeat1_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.74s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_3_mod_agg_fold3_repeat2_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.83s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_3_mod_agg_fold4_repeat0_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.90s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_3_mod_agg_fold4_repeat1_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.82s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_3_mod_agg_fold4_repeat2_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 4.08s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_4_mod_agg_fold0_repeat0_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.73s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_4_mod_agg_fold0_repeat1_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.72s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_4_mod_agg_fold0_repeat2_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.98s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_4_mod_agg_fold1_repeat0_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.83s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_4_mod_agg_fold1_repeat1_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.78s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_4_mod_agg_fold1_repeat2_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 4.05s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_4_mod_agg_fold2_repeat0_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.99s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_4_mod_agg_fold2_repeat1_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.85s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_4_mod_agg_fold2_repeat2_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.89s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_4_mod_agg_fold3_repeat0_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.79s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_4_mod_agg_fold3_repeat1_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.81s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_4_mod_agg_fold3_repeat2_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.96s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_4_mod_agg_fold4_repeat0_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.70s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_4_mod_agg_fold4_repeat1_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.79s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_4_mod_agg_fold4_repeat2_bs64_ne8_lr0.0001/
# loaded model
# generated scores in 3.97s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_5_mod_agg_fold0_repeat0_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.89s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_5_mod_agg_fold0_repeat1_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.85s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_5_mod_agg_fold0_repeat2_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.93s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_5_mod_agg_fold1_repeat0_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.98s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_5_mod_agg_fold1_repeat1_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.88s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_5_mod_agg_fold1_repeat2_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.90s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_5_mod_agg_fold2_repeat0_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.69s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_5_mod_agg_fold2_repeat1_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.94s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_5_mod_agg_fold2_repeat2_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.91s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_5_mod_agg_fold3_repeat0_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.83s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_5_mod_agg_fold3_repeat1_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.95s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_5_mod_agg_fold3_repeat2_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.87s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_5_mod_agg_fold4_repeat0_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 4.01s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_5_mod_agg_fold4_repeat1_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.80s
# singletask-events_GAIN.19.108003.58617616_hpt_fold_5_mod_agg_fold4_repeat2_bs64_ne4_lr0.0001/
# loaded model
# generated scores in 3.81s

# %%
###########################
## EVALUATE SINGLE MODEL ##
###########################

## Path to main work directory
pwd = "/Users/willembonnaffe/Documents/Academia/Projects/PAW-MIL-2D-PPCG/outputs/PPCG_MQ_SmallMediumNozeroNew_256_MultiTask_Augmented_all/"

## Relative paths
pt_embeddings_file = pwd + "encoder/obj_embeddings.pkl"
pt_labels_file = pwd + "aggregator-1000-singletask/singletask-clinical_gleason_index_1/tab_labels.txt"
pt_model_file = pwd + "aggregator-1000-singletask/singletask-clinical_gleason_index_1/hypertrain_fold_1/models/mod_agg_fold0_repeat0_bs32_ne4_lr0.001.pth"
pt_output_folder = "/Users/willembonnaffe/Desktop/Test/"

## Apply aggregator
main_apply_aggregator_single(
    pt_embeddings_file,
    pt_labels_file, 
    pt_model_file,
    pt_output_folder,
    device = "mps"
    )

#
###
# Out:
# loaded model
# generated scores in 11.93s
