# %%
##############
## INITIATE ##
##############

## Imports
import os
import numpy as np
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.lines import Line2D

## Import modules
from p_pawmil.m_apply_aggregator import main_apply_aggregator_single

#
###

# %%
##############################
## EVALUATE MULTIPLE MODELS ##
##############################

## Path to main work directory
pwd = "/Volumes/Elements/BDI/projects/GSG/outputs/o3_mil/tcga-oct/model_resnet_tcgaoct_raw_FTL_3/"

## Path to embeddings
pt_embeddings_file = pwd + "encoder/obj_embeddings.pkl"

## Move to aggregator directory
pwd = pwd + "aggregator/singletask-EMT.GAIN/"
hp_star = np.genfromtxt(pwd + "tab_best_hyperparameters.csv", delimiter=",", dtype="str")

## For each label
for hp_star_ in hp_star[1:]: # Skip header

    ## Strip hypertrain metadata
    label, fold, hp = hp_star_    
    bs, ne, lr = str.split(hp, "_")    
    bs = int(float(bs))
    ne = int(float(ne))

    ## Get labels
    pt_labels_file = pwd + f"{label}/tab_labels.txt"        

    ## Path to output
    pt_output_folder = pwd + f"{label}/predictions/"
    if os.path.exists(pt_output_folder) == False:
        os.mkdir(pt_output_folder)
    
    ## For each model
    for val_fold_idx_ in [0, 1, 2, 3, 4]:
        for repeat_idx_ in [0, 1, 2]:
            
            ## Get model id and path to model file
            model_id = f"mod_agg_fold{val_fold_idx_}_repeat{repeat_idx_}_bs{bs}_ne{ne}_lr{lr}"    
            pt_model_file = pwd + f"{label}/hypertrain_fold_{fold}/models/{model_id}.pth"

            ## Output subfolder
            pt_output_folder_ = pt_output_folder + f"{label}_hpt_fold_{fold}_{model_id}/"
            if os.path.exists(pt_output_folder_) == False:
                os.mkdir(pt_output_folder_)

            ## Message 
            print(f"{label}_hpt_fold_{fold}_{model_id}")
            
            ## Apply aggregator
            main_apply_aggregator_single(
                pt_embeddings_file,
                pt_labels_file, 
                pt_model_file,
                pt_output_folder_,
                device = "mps"
                )

#
###
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 13
#      11 ## Move to aggregator directory
#      12 pwd = pwd + "aggregator/singletask-EMT.GAIN/"
# ---> 13 hp_star = np.genfromtxt(pwd + "tab_best_hyperparameters.csv", delimiter=",", dtype="str")
#      15 ## For each label
#      16 for hp_star_ in hp_star[1:]: # Skip header
#      17
#      18     ## Strip hypertrain metadata
#
# File /opt/anaconda3/envs/pytorch/lib/python3.8/site-packages/numpy/lib/npyio.py:1977, in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding, ndmin, like)
#    1975     fname = os_fspath(fname)
#    1976 if isinstance(fname, str):
# -> 1977     fid = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#    1978     fid_ctx = contextlib.closing(fid)
#    1979 else:
#
# File /opt/anaconda3/envs/pytorch/lib/python3.8/site-packages/numpy/lib/_datasource.py:193, in open(path, mode, destpath, encoding, newline)
#     156 """
#     157 Open `path` with `mode` and return the file object.
#     158
#    (...)
#     189
#     190 """
#     192 ds = DataSource(destpath)
# --> 193 return ds.open(path, mode, encoding=encoding, newline=newline)
#
# File /opt/anaconda3/envs/pytorch/lib/python3.8/site-packages/numpy/lib/_datasource.py:533, in DataSource.open(self, path, mode, encoding, newline)
#     530     return _file_openers[ext](found, mode=mode,
#     531                               encoding=encoding, newline=newline)
#     532 else:
# --> 533     raise FileNotFoundError(f"{path} not found.")
#
# FileNotFoundError: /Volumes/Elements/BDI/projects/GSG/outputs/o3_mil/tcga-oct/model_resnet_tcgaoct_raw_FTL_3/aggregator/singletask-EMT.GAIN/tab_best_hyperparameters.csv not found.
